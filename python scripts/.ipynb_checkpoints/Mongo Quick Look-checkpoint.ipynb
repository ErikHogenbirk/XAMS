# %%
from pymongo import MongoClient
import matplotlib.pyplot as plt
import snappy
import numpy as np
from scipy import stats  
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
client = MongoClient()
dbname = 'xamsdata0'

# %% [markdown]
# ### Plot a waveform

# %%
collname = '190129_134455'  #run name from http://localhost:8080/

# %%
doc.keys()
# Out:
# dict_keys(['channel', 'data', 'module', 'time', '_id', 'endtime'])

# %%
cursor = client[dbname][collname].find()
i = 0
data = []

t_1724 = []
t_1730 = []

for doc in cursor:
    if doc['module'] == 1724:
        t_1724.append(doc['time'])
    elif doc['module'] == 1730:
        t_1730.append(doc['time'])
    else:
        print('WTF?')
#     d = snappy.decompress(doc['data'])
#     w = np.fromstring(d, dtype='<i2')
#     print(doc['channel'])
#     print(doc['module'])
#     plt.plot(w)
#     break

# %%
(np.diff(t_1724) / 1e9) * 10
# Out:
# array([ 0.09998186,  0.09998186,  0.09998184,  0.09998186,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998184,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998186,  0.09998184,  0.09998186,  0.09998186,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998184,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998184,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998184,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998184,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998186,  0.09998184,  0.09998186,  0.09998186,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998184,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998186,  0.09998186,  0.09998184,  0.09998186,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998184,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998184,  0.09998186,
#         0.09998186,  0.09998186,  0.09998186,  0.09998186,  0.09998186,
#         0.09998184,  0.09998186,  0.09998186,  0.09998186])

# %%
(np.diff(t_1730) / 1e9) * 8
# Out:
# array([ 0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000195,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197,  0.10000197,
#         0.10000197,  0.10000197,  0.10000197,  0.10000197])

# %%
t_1724
# Out:
# [3623284,
#  13621470,
#  23619656,
#  33617840,
#  43616026,
#  53614212,
#  63612398,
#  73610584,
#  83608770,
#  93606954,
#  103605140,
#  113603326,
#  123601512,
#  133599698,
#  143597882,
#  153596068,
#  163594254,
#  173592440,
#  183590626,
#  193588810,
#  203586996,
#  213585182,
#  223583368,
#  233581554,
#  243579738,
#  253577924,
#  263576110,
#  273574296,
#  283572482,
#  293570666,
#  303568852,
#  313567038,
#  323565224,
#  333563410,
#  343561596,
#  353559782,
#  363557966,
#  373556152,
#  383554338,
#  393552524,
#  403550710,
#  413548896,
#  423547080,
#  433545266,
#  443543452,
#  453541638,
#  463539824,
#  473538010,
#  483536196,
#  493534382,
#  503532566,
#  513530752,
#  523528938,
#  533527124,
#  543525310,
#  553523494,
#  563521680,
#  573519866,
#  583518052,
#  593516238,
#  603514422,
#  613512608,
#  623510794,
#  633508980,
#  643507166,
#  653505352,
#  663503536,
#  673501722,
#  683499908,
#  693498094,
#  703496280,
#  713494466,
#  723492650,
#  733490836,
#  743489022,
#  753487208,
#  763485394,
#  773483580,
#  783481766,
#  793479950,
#  803478136,
#  813476322,
#  823474508,
#  833472694,
#  843470880,
#  853469064,
#  863467250,
#  873465436,
#  883463622,
#  893461808,
#  903459994,
#  913458180,
#  923456366,
#  933454550,
#  943452736,
#  953450922,
#  963449108,
#  973447294,
#  983445480,
#  993443666,
#  1003441852,
#  1013440036,
#  1023438222,
#  1033436408,
#  1043434594,
#  1053432780,
#  1063430966,
#  1073429152,
#  1083427338,
#  1093425522,
#  1103423708,
#  1113421894,
#  1123420080,
#  1133418266,
#  1143416452,
#  1153414638,
#  1163412822,
#  1173411008,
#  1183409194,
#  1193407380]

# %%
plt.plot(np.array(t_1724)*10)
plt.plot(np.array(t_1730) * 8)

# %%
cursor = client[dbname][collname].find()
i = 0
data = []
for doc in cursor:
    d = snappy.decompress(doc['data'])
    w = np.fromstring(d, dtype='<i2')
    # w_c = w - np.mean(w[:100])
    
    # 
    if doc['channel'] == 4:
        continue
    data.append(w)
    
#     plt.plot(w)
#     if doc['channel'] == 0:
#         plt.plot(np.linspace(0, 0.002*len(w_c), len(w_c)),
#                  w_c, alpha = 0.5, color = 'blue')
#     if doc['channel'] == 3:
#         w_c -= 300
#         plt.plot(np.linspace(0, 0.002*len(w_c), len(w_c)),
#             w_c, alpha = 0.5, color = 'red')
#         plt.xlabel('us')
#         plt.ylim(-1000,100)
#         plt.savefig('signal.pdf', format = 'pdf')
#         plt.show()
#     if doc['channel'] == 4:
#         print(len(w))
#         plt.plot(w, color = 'black')
#         plt.axvline(1000)
#         plt.show()
#     i+=1
#     if i > 3:
#         break

# %%
time = np.linspace(0, len(data[0]) * 2, len(data[0]) + 1)[:-1] 
conversion = 0.5 * 1/(2**14) #in Volts per bit

# #raw waveform
# for i in range(2000):
#     baseline = np.average(data[i][:100]) #find the average value of the baseline using first 100 samples
#     plt.figure(1)
#     wf = ((data[i]-baseline)*conversion)*1000
#     plt.title('filterd waveforms for SiPM #13 at bias = 59 V')
#     plt.ylabel('Amplitude [mV]')
#     plt.xlabel('Time [ns]')
#     plt.plot(time,wf, alpha = 0.05) 
#     plt.xlim(640,840)


#wf in expected signal region
area = []
for i in range(len(data)):
    baseline = np.average(data[i][:100]) #find the average value of the baseline using first 100 samples
    wf = ((data[i]-baseline)*conversion)*1000 #find the max DAQ voltage value (in mV)
    wf_max = np.max(wf) #in mV (i.e. 0.0045V*1000 see above)
    wf_max_time = np.argmax(wf) #find DAQ time value corresponding to max_wf ~335 (x2 for actual time)
    wf_adjust = []
    time_adjust = []
    t = 0
    if wf_max > 1 and wf_max < 2.25: #skips wf with no pulse and keeps 1p.e. pulses
        if wf_max_time > 320 and wf_max_time < 340: #filters out wf with max outside of expected wf
            for j in range(wf_max_time-6,wf_max_time + 80):
                point = ((data[i][j]-baseline)*conversion)*1000 #in mV
                wf_adjust.append(point)
                time_adjust.append(t)
                t = t+1     
            plt.figure(2)
            plt.title('filterd waveforms for SiPM #13 at bias = 59 V')
            plt.ylabel('Amplitude [mV]')
            plt.xlabel('Time [ns]')
            plt.plot(time_adjust,wf_adjust, alpha = 1)
    area.append(np.sum(wf_adjust))


# filter out wf with PT or AP
# for k in range(len(wf_adjust))


area_positive = []
for r in range(len(area)):
    if area[r] > 0:
        area_positive.append(area[r])
        
plt.figure(3)
plt.hist(area_positive, normed = True, bins = 300)
plt.title('distribution of single p.e. area')
plt.ylabel('counts')
plt.xlabel('area (mV ns)')

area_mean = np.mean(area)*1e-12 #in Vs
q = 1.602e-19 #unit charge in C
R = 50 #impedance in ohm
gain = area_mean/(R*q)
print("The 1p.e. gain is:")
print("{:.2e}".format(gain))
# Out:
# The 1p.e. gain is:
# 4.16e+04

# %% [markdown]
# ### Noise analysis

# %%
# 170227_104148 is 160 microsecond samples of nothing at 1000V for both PMTs, using 0 gain for both
# 170227_122330 is 160 microsecond samples of nothing at 1000V for both PMTs, using 1 gain for both
# The above 2 are baseline mode 0  and 809c (autocal) 1

# 170227_132952 is baseline mode 2
# baselines pretty much the same

# 170227_133203 is same but after ADC reset
# baselines shifted to the right by about 50 counts or so

# baseline_mode 1 leads to error initializing electronics. The baseline files do not exist.
# baseline mode set back to 2

# 170227_134002 is with 8098 at 8000
# 170227_134137 is with 8098 at C000
# 170227_134349 is after reset
# 170227_134711 is with 1098 C000
# 170227_134838 is with 809C 0
# None of these things (except the reset) affect the baselines
# 170227_135429 is with all register settings about baseline removed

# started a bunch of short runs (10s) with standard default ini
# these runs start at 170227_140328 with exactly 20 seconds in between til 170227_140708
# results: 
# 8266 8229
# 8268 8230
# 8266 8229
# 8268 8230
# 8267 8229
# 8267 8230
# 8267 8229
# 8268 8230
# 8266 8229
# So very consistent

# Started a bunch of runs like this but resetting the ADC every time
# These are the runs between 170227_141723 and 170227_143127
# results: 
# 8269 8234
# 8270 8225
# 8271 8232
# 8269 8234
# 8287 8252
# 8267 8232
# 8268 8241
# 8286 8242
# 8269 8218
# 8268 8232

# %%
dbname = 'xamsdata0'
collname = '180315_130616'
cursor = client[dbname][collname].find()
i = 0
l = []
c = []
for doc in cursor:
    d = snappy.decompress(doc['data'])
    w = list(np.fromstring(d, dtype='<i2'))
#     print(doc['channel'])
    l.append(w)
    c.append(doc['channel'])
    
# print(l[5])

# %%
for i in [0, 1, 2]:
    plt.plot(l[i], label = 'channel %d' % (c[i]))
    print('Channel %d baseline: %.2f' % (c[i], np.sum(l[i][:200])/200))
plt.legend()
plt.xlim(0, 200)
plt.ylim(8000, 8400)
plt.show()
# Out:
# Channel 0 baseline: 8189.78
# Channel 3 baseline: 8255.78
# Channel 4 baseline: 8268.42

# %%
l[0]
# Out:
# [8196,
#  8193,
#  8191,
#  8191,
#  8190,
#  8194,
#  8192,
#  8191,
#  8193,
#  8194,
#  8194,
#  8198,
#  8195,
#  8191,
#  8195,
#  8194,
#  8192,
#  8193,
#  8193,
#  8195,
#  8193,
#  8194,
#  8194,
#  8194,
#  8190,
#  8193,
#  8195,
#  8191,
#  8190,
#  8193,
#  8195,
#  8195,
#  8194,
#  8191,
#  8193,
#  8193,
#  8195,
#  8193,
#  8193,
#  8193,
#  8194,
#  8194,
#  8195,
#  8193,
#  8190,
#  8190,
#  8190,
#  8195,
#  8194,
#  8194,
#  8191,
#  8192,
#  8192,
#  8195,
#  8189,
#  8190,
#  8194,
#  8190,
#  8195,
#  8191,
#  8199,
#  8193,
#  8192,
#  8195,
#  8192,
#  8191,
#  8195,
#  8193,
#  8195,
#  8191,
#  8193,
#  8190,
#  8194,
#  8190,
#  8192,
#  8192,
#  8189,
#  8193,
#  8195,
#  8194,
#  8194,
#  8194,
#  8193,
#  8192,
#  8195,
#  8193,
#  8192,
#  8193,
#  8194,
#  8194,
#  8192,
#  8194,
#  8195,
#  8196,
#  8188,
#  8193,
#  8195,
#  8193,
#  8190,
#  8195,
#  8194,
#  8190,
#  8195,
#  8194,
#  8191,
#  8190,
#  8194,
#  8190,
#  8192,
#  8194,
#  8193,
#  8194,
#  8194,
#  8194,
#  8192,
#  8191,
#  8195,
#  8193,
#  8195,
#  8193,
#  8195,
#  8190,
#  8192,
#  8190,
#  8199,
#  8194,
#  8192,
#  8194,
#  8195,
#  8190,
#  8192,
#  8192,
#  8191,
#  8194,
#  8196,
#  8192,
#  8194,
#  8193,
#  8196,
#  8191,
#  8193,
#  8197,
#  8193,
#  8193,
#  8193,
#  8193,
#  8195,
#  8193,
#  8194,
#  8196,
#  8195,
#  8190,
#  8193,
#  8197,
#  8191,
#  8196,
#  8195,
#  8194,
#  8195,
#  8194,
#  8192,
#  8193,
#  8196,
#  8194,
#  8193,
#  8191,
#  8196,
#  8194,
#  8196,
#  8193,
#  8193,
#  8193,
#  8193,
#  8192,
#  8194,
#  8195,
#  8193,
#  8191,
#  8195,
#  8194,
#  8194,
#  8194,
#  8191,
#  8194,
#  8196,
#  8194,
#  8195,
#  8201,
#  8194,
#  8193,
#  8198,
#  8192,
#  8194,
#  8194,
#  8196,
#  8194,
#  8195,
#  8194,
#  8191,
#  8194,
#  8196,
#  8196,
#  8193,
#  8195,
#  8195,
#  8193,
#  8190,
#  8194,
#  8199,
#  8193,
#  8196,
#  8194,
#  8194,
#  8194,
#  8194,
#  8195,
#  8198,
#  8193,
#  8195,
#  8196,
#  8195,
#  8194,
#  8194,
#  8194,
#  8194,
#  8194,
#  8194,
#  8197,
#  8196,
#  8196,
#  8194,
#  8195,
#  8194,
#  8195,
#  8193,
#  8197,
#  8191,
#  8193,
#  8194,
#  8196,
#  8192,
#  8194,
#  8194,
#  8193,
#  8194,
#  8190,
#  8194,
#  8194,
#  8193,
#  8195,
#  8196,
#  8198,
#  8194,
#  8193,
#  8193,
#  8194,
#  8193,
#  8193,
#  8195,
#  8201,
#  8197,
#  8191,
#  8196,
#  8195,
#  8195,
#  8195,
#  8192,
#  8195,
#  8192,
#  8191,
#  8196,
#  8194,
#  8195,
#  8193,
#  8198,
#  8194,
#  8192,
#  8192,
#  8196,
#  8193,
#  8191,
#  8194,
#  8194,
#  8195,
#  8196,
#  8189,
#  8192,
#  8194,
#  8191,
#  8192,
#  8195,
#  8195,
#  8199,
#  8193,
#  8194,
#  8193,
#  8196,
#  8196,
#  8195,
#  8194,
#  8195,
#  8191,
#  8192,
#  8194,
#  8195,
#  8195,
#  8197,
#  8194,
#  8195,
#  8195,
#  8194,
#  8197,
#  8194,
#  8194,
#  8192,
#  8194,
#  8190,
#  8193,
#  8194,
#  8194,
#  8194,
#  8194,
#  8196,
#  8193,
#  8194,
#  8192,
#  8188,
#  8192,
#  8196,
#  8191,
#  8195,
#  8194,
#  8192,
#  8192,
#  8192,
#  8195,
#  8189,
#  8191,
#  8195,
#  8191,
#  8194,
#  8195,
#  8194,
#  8194,
#  8192,
#  8198,
#  8193,
#  8194,
#  8195,
#  8193,
#  8195,
#  8192,
#  8195,
#  8195,
#  8190,
#  8194,
#  8194,
#  8196,
#  8195,
#  8193,
#  8197,
#  8190,
#  8196,
#  8191,
#  8195,
#  8193,
#  8194,
#  8193,
#  8192,
#  8195,
#  8195,
#  8194,
#  8192,
#  8194,
#  8193,
#  8194,
#  8194,
#  8194,
#  8195,
#  8192,
#  8194,
#  8193,
#  8194,
#  8194,
#  8194,
#  8194,
#  8194,
#  8193,
#  8194,
#  8191,
#  8195,
#  8193,
#  8196,
#  8199,
#  8190,
#  8192,
#  8195,
#  8197,
#  8192,
#  8193,
#  8196,
#  8190,
#  8195,
#  8193,
#  8195,
#  8197,
#  8195,
#  8189,
#  8199,
#  8193,
#  8194,
#  8192,
#  8195,
#  8194,
#  8190,
#  8192,
#  8195,
#  8193,
#  8195,
#  8193,
#  8197,
#  8190,
#  8192,
#  8194,
#  8192,
#  8193,
#  8194,
#  8190,
#  8195,
#  8194,
#  8193,
#  8192,
#  8193,
#  8193,
#  8194,
#  8189,
#  8192,
#  8196,
#  8190,
#  8193,
#  8195,
#  8194,
#  8192,
#  8194,
#  8194,
#  8195,
#  8194,
#  8194,
#  8195,
#  8194,
#  8195,
#  8195,
#  8195,
#  8195,
#  8195,
#  8191,
#  8195,
#  8193,
#  8195,
#  8194,
#  8194,
#  8191,
#  8195,
#  8194,
#  8194,
#  8194,
#  8194,
#  8193,
#  8200,
#  8194,
#  8195,
#  8194,
#  8194,
#  8196,
#  8195,
#  8196,
#  8195,
#  8192,
#  8196,
#  8191,
#  8194,
#  8193,
#  8192,
#  8194,
#  8199,
#  8193,
#  8195,
#  8192,
#  8194,
#  8193,
#  8193,
#  8199,
#  8194,
#  8197,
#  8195,
#  8191,
#  8195,
#  8192,
#  8193,
#  8195,
#  8196,
#  8193,
#  8195,
#  8193,
#  8193,
#  8194,
#  8197,
#  8193,
#  8194,
#  8194,
#  8194,
#  8191,
#  8195,
#  8192,
#  8197,
#  8197,
#  8195,
#  8195,
#  8198,
#  8197,
#  8192,
#  8197,
#  8194,
#  8194,
#  8193,
#  8194,
#  8194,
#  8190,
#  8197,
#  8193,
#  8197,
#  8193,
#  8194,
#  8196,
#  8194,
#  8193,
#  8195,
#  8193,
#  8197,
#  8193,
#  8196,
#  8193,
#  8192,
#  8198,
#  8194,
#  8194,
#  8198,
#  8196,
#  8195,
#  8194,
#  8194,
#  8192,
#  8194,
#  8197,
#  8197,
#  8192,
#  8198,
#  8196,
#  8194,
#  8197,
#  8195,
#  8194,
#  8195,
#  8196,
#  8193,
#  8197,
#  8194,
#  8193,
#  8195,
#  8194,
#  8198,
#  8198,
#  8194,
#  8194,
#  8193,
#  8193,
#  8194,
#  8193,
#  8194,
#  8193,
#  8195,
#  8190,
#  8195,
#  8194,
#  8195,
#  8190,
#  8195,
#  8193,
#  8194,
#  8193,
#  8193,
#  8194,
#  8190,
#  8195,
#  8190,
#  8195,
#  8191,
#  8193,
#  8194,
#  8194,
#  8195,
#  8194,
#  8194,
#  8195,
#  8193,
#  8196,
#  8195,
#  8194,
#  8196,
#  8194,
#  8198,
#  8194,
#  8194,
#  8193,
#  8193,
#  8194,
#  8194,
#  8192,
#  8192,
#  8194,
#  8193,
#  8196,
#  8195,
#  8196,
#  8190,
#  8196,
#  8196,
#  8192,
#  8193,
#  8193,
#  8195,
#  8194,
#  8192,
#  8195,
#  8192,
#  8191,
#  8195,
#  8196,
#  8194,
#  8194,
#  8195,
#  8198,
#  8195,
#  8194,
#  8197,
#  8193,
#  8195,
#  8193,
#  8192,
#  8193,
#  8196,
#  8196,
#  8195,
#  8193,
#  8192,
#  8193,
#  8195,
#  8193,
#  8195,
#  8197,
#  8194,
#  8192,
#  8197,
#  8190,
#  8195,
#  8194,
#  8194,
#  8192,
#  8195,
#  8193,
#  8194,
#  8195,
#  8195,
#  8196,
#  8195,
#  8194,
#  8195,
#  8192,
#  8195,
#  8192,
#  8195,
#  8192,
#  8195,
#  8192,
#  8193,
#  8194,
#  8194,
#  8192,
#  8194,
#  8190,
#  8194,
#  8193,
#  8194,
#  8193,
#  8194,
#  8194,
#  8194,
#  8190,
#  8193,
#  8194,
#  8198,
#  8195,
#  8195,
#  8193,
#  8198,
#  8192,
#  8199,
#  8195,
#  8195,
#  8195,
#  8194,
#  8193,
#  8198,
#  8197,
#  8193,
#  8196,
#  8195,
#  8199,
#  8195,
#  8190,
#  8194,
#  8195,
#  8195,
#  8192,
#  8196,
#  8196,
#  8196,
#  8191,
#  8195,
#  8195,
#  8195,
#  8197,
#  8196,
#  8195,
#  8196,
#  8195,
#  8193,
#  8196,
#  8196,
#  8192,
#  8196,
#  8193,
#  8194,
#  8196,
#  8194,
#  8196,
#  8196,
#  8196,
#  8193,
#  8194,
#  8195,
#  8194,
#  8195,
#  8193,
#  8194,
#  8194,
#  8194,
#  8197,
#  8191,
#  8193,
#  8194,
#  8194,
#  8196,
#  8193,
#  8196,
#  8195,
#  8194,
#  8190,
#  8194,
#  8192,
#  8195,
#  8193,
#  8194,
#  8196,
#  8195,
#  8195,
#  8189,
#  8193,
#  8193,
#  8192,
#  8194,
#  8196,
#  8195,
#  8192,
#  8194,
#  8193,
#  8196,
#  8193,
#  8195,
#  8193,
#  8192,
#  8194,
#  8193,
#  8193,
#  8194,
#  8192,
#  8190,
#  8195,
#  8195,
#  8194,
#  8190,
#  8193,
#  8193,
#  8194,
#  8195,
#  8193,
#  8194,
#  8198,
#  8190,
#  8194,
#  8195,
#  8194,
#  8197,
#  8193,
#  8192,
#  8195,
#  8196,
#  8193,
#  8194,
#  8197,
#  8194,
#  8192,
#  8194,
#  8194,
#  8195,
#  8193,
#  8195,
#  8192,
#  8195,
#  8190,
#  8189,
#  8193,
#  8193,
#  8195,
#  8194,
#  8193,
#  8195,
#  8191,
#  8188,
#  8193,
#  8194,
#  8193,
#  8195,
#  8191,
#  8196,
#  8192,
#  8196,
#  8192,
#  8188,
#  8198,
#  8197,
#  8195,
#  8193,
#  8196,
#  8193,
#  8192,
#  8193,
#  8194,
#  8193,
#  8192,
#  8197,
#  8193,
#  8195,
#  8193,
#  8190,
#  8193,
#  8194,
#  8192,
#  8192,
#  8196,
#  8194,
#  8193,
#  8195,
#  8195,
#  8195,
#  8193,
#  8195,
#  8193,
#  8191,
#  8192,
#  8191,
#  8193,
#  8195,
#  8194,
#  8193,
#  8195,
#  8193,
#  8190,
#  8195,
#  8192,
#  8195,
#  8194,
#  8194,
#  8193,
#  8192,
#  8193,
#  8192,
#  8193,
#  8191,
#  8194,
#  8196,
#  8191,
#  8194,
#  8195,
#  8192,
#  8195,
#  8195,
#  8195,
#  8196,
#  8190,
#  8193,
#  8193,
#  8194,
#  8192,
#  8195,
#  8193,
#  8190,
#  8195,
#  8195,
#  8193,
#  8194,
#  8193,
#  8194,
#  8194,
#  8192,
#  8192,
#  8191,
#  8193,
#  8197,
#  8192,
#  8192,
#  8194,
#  8195,
#  8191,
#  8194,
#  8194,
#  8192,
#  8194,
#  8192,
#  8196,
#  8194,
#  8192,
#  8190,
#  8193,
#  8194,
#  8191,
#  8195,
#  8195,
#  8194,
#  8193,
#  8195,
#  8194,
#  8194,
#  8193,
#  8194,
#  8195,
#  8192,
#  8194,
#  8194,
#  8196,
#  8194,
#  8194,
#  8198,
#  8192,
#  8194,
#  8193,
#  8194,
#  8194,
#  8193,
#  8193,
#  8191,
#  8197,
#  8192,
#  8194,
#  8190,
#  8192,
#  8189,
#  8193,
#  8197,
#  8193,
#  8195,
#  8194,
#  8194,
#  8192,
#  8192,
#  8193,
#  8196,
#  8195,
#  8191,
#  8193,
#  8195,
#  8194,
#  8193,
#  8194,
#  8194,
#  8191,
#  8195,
#  8195,
#  8192,
#  8195,
#  ...]

# %%
# Out:
# [0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3,
#  0,
#  3]

# %%
c = np.array(c)
l = np.array(l)

# %%
sel = (np.array(c) == 3)

# %%
i = 0
for doc in cursor:
#     i += 1
    d = snappy.decompress(doc['data'])
    w = list(np.fromstring(d, dtype='<i2'))
#     print(doc['channel'])
    if doc['channel'] == 3:
        plt.plot(w)
        i +=1
    if i > 200:
        break
    plt.xlim(300, 400)

# %%
histboundaries = [8150.5,8350.5]
histbinwidth = 1
histbins = np.arange(histboundaries[0], histboundaries[1]+histbinwidth, histbinwidth)
centers = np.arange(histboundaries[0]+histbinwidth/2.0, histboundaries[1], histbinwidth)

print(c[0])
print(c[1])
histpmt2 = plt.hist(l[20], bins=histbins, histtype='step', color = 'red')
plt.xlabel('adc counts')
plt.ylabel('counts')
plt.show()

print(c[1])
histpmt1 = plt.hist(l[21], bins=histbins, histtype='step', color = 'red')
plt.xlabel('adc counts')
plt.ylabel('counts')
plt.show()

counts1 = histpmt1[0]
counts1err = [np.sqrt(c)+1 for c in counts1]
counts2 = histpmt2[0]
counts2err = [np.sqrt(c)+1 for c in counts2]
# Out:
# 0
# 3
# 3

# %%
def gauss(x, a1, b1, s1):
    return a1 * np.exp(-(x-b1)**2/(2*s1**2))

ag = 12000
bg = 8240
sg = 50

popt1, pcov1 = curve_fit(gauss, centers, counts1, sigma = counts1err, p0=[ag, bg, sg])
perr1 = np.sqrt(np.diag(pcov1))
af1, bf1, sf1 = popt1

popt2, pcov2 = curve_fit(gauss, centers, counts2, sigma = counts2err, p0=[ag, bg, sg])
perr2 = np.sqrt(np.diag(pcov2))
af2, bf2, sf2 = popt2

fitcounts1 = [gauss(t, popt1[0], popt1[1], popt1[2]) for t in centers]
fitcounts2 = [gauss(t, popt2[0], popt2[1], popt2[2]) for t in centers]
gescounts = [gauss(t, ag, bg, sg) for t in centers]

plt.errorbar(centers, counts1, yerr = counts1err, fmt = '.', markersize = 4, color = 'black')
plt.errorbar(centers, counts2, yerr = counts2err, fmt = '.', markersize = 4, color = 'red')
plt.plot(centers, fitcounts1, color='grey', linewidth = 2)
plt.plot(centers, fitcounts2, color='pink', linewidth = 2)
# plt.plot(centers, gescounts, color='black', linewidth = 1)
plt.xlabel("ADC counts")
plt.ylabel("counts")
# plt.yscale('log')
plt.xlim(8150, 8350)
# plt.ylim(0,1)
plt.savefig('gaussness_gain1(donottrustanylikethis)', format='eps')
plt.show()

print(popt1[1], popt2[1])
# Out:
# 8259.74041931 8192.10468328

# %%
centersheight1 = [(c-popt1[1])*500/16384 for c in centers]
centersheight2 = [(c-popt2[1])*500/16384 for c in centers]
countsheight1 = np.cumsum(counts1[::-1])[::-1]
countsheight2 = np.cumsum(counts2[::-1])[::-1]
plt.plot(centersheight1, countsheight1, color = 'black')
plt.plot(centersheight2, countsheight2, color = 'red')
plt.xlim(0,2)
plt.ylim(0,1000)
plt.xlabel('threshold(mV)')
plt.ylabel('dark hits per 160 micros')
plt.savefig('noise_accept.pdf', format='pdf')
plt.show()

# %% [markdown]
# ### Baseline scatter plot

# %%
baseline1 = [8269, 8270, 8271, 8269, 8287, 8267, 8268, 8286, 8269, 8268]
baseline2 = [8234, 8225, 8232, 8234, 8252, 8232, 8241, 8242, 8218, 8232]

plt.scatter(baseline1, baseline2, alpha=0.5)
plt.savefig('reset_baselines.pdf', format='pdf')
plt.show()

import statistics
print(statistics.mean(baseline1), statistics.stdev(baseline1))
print(statistics.mean(baseline2), statistics.stdev(baseline2))
# Out:
# 8272.4 7.515909052728677
# 8234.2 9.342852288722588

# %% [markdown]
# ### Radon analysis

# %%
hex(8192-410)
# Out:
# '0x1fd7'

# %%
dbname = 'xamsdata0'
collname = '170213_105309'
client[dbname][collname]
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'xamsdata0'), '170213_105309')

# %%
import pandas as pd
n_events = client[dbname][collname].count()//2
print('Maximum usable events now: %d' % n_events)
    
df = pd.DataFrame({'time': np.zeros(n_events), 
                   'time_ns': np.zeros(n_events, dtype=int), 
                   'baseline_ch0' : np.zeros(n_events),
                   'baseline_ch0_' : np.zeros(n_events),

                   'baseline_ch4' : np.zeros(n_events),
                   'plateau_ch0' : np.zeros(n_events),
                   'max_ch0' : np.zeros(n_events),
                   'min_ch4' : np.zeros(n_events),
                  })
# Out:
# Maximum usable events now: 11703

# %%
cursor = client[dbname][collname].find()
i = 0
for doc in cursor:
    if i >= n_events * 2:
        break
    i_ev = i//2 # 2 channels
    # Get the data
    d = snappy.decompress(doc['data'])
    w = np.fromstring(d, dtype='<i2')
    # 
    if doc['channel'] == 0:
        # New event! Let us store all the relevant properties
        df.iloc[i_ev, df.columns.get_loc('time_ns')] = doc['time'] * 4
        df.iloc[i_ev, df.columns.get_loc('time')] = doc['time'] * 4 * 1e-9
        df.iloc[i_ev, df.columns.get_loc('baseline_ch0_')] = np.average(w[:100])
        df.iloc[i_ev, df.columns.get_loc('baseline_ch0')] = np.average(w[:250])

        df.iloc[i_ev, df.columns.get_loc('plateau_ch0')] = np.average(w[400:600])
        df.iloc[i_ev, df.columns.get_loc('max_ch0')] = max(w)
    if doc['channel'] == 4:
        df.iloc[i_ev, df.columns.get_loc('baseline_ch4')] = np.average(w[:100])
        df.iloc[i_ev, df.columns.get_loc('min_ch4')] = max(w)
    i+=1

# %%
df['amp'] = df['plateau_ch0'] - df['baseline_ch0']

# %%
shift = 30
plt.hist(df['amp'], bins=300, histtype='step', 
         range=(-shift,400 - shift))
plt.xlim(-shift,400 - shift)
plt.twiny()
plt.hist(df['plateau_ch0'], bins=300, histtype='step', range=(8200,8600), color='green')
#plt.hist(df['baseline_ch0'], bins=300, histtype='step', range=(8200,8600))

# plt.yscale('log')
# plt.ylim(1,1e3)
plt.show()

# %%
bin_counts, bin_edges, _ = plt.hist(df['amp'], 
                                    bins=1000, histtype='step', range=(100,300))
# plt.yscale('log')
# plt.ylim(1, 4e2)
plt.axvline(205)
plt.axvline(230)

plt.axvline(265)
plt.axvline(290)

plt.show()

# %%
def get_peak_properties(start_at, stop_at, bin_counts, bin_edges):
    bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
    peak0_max = max(bin_counts[start_at:stop_at])
    peak0_index = start_at + np.argmax(bin_counts[start_at:stop_at])
    peak0_pos = bin_centers[peak0_index]
    i = peak0_index
    while bin_counts[i] >= 0.5 * peak0_max:
        i -= 1
    peak0_left = bin_centers[i]
    peak0_left_samples = i
    i = peak0_index
    while bin_counts[i] >= 0.5 * peak0_max:
        i += 1
    peak0_right = bin_centers[i]
    peak0_right_samples = i
    peak0_fwhm = (peak0_right - peak0_left) / peak0_pos * 100
    print('Returning properties of peak found at %.1f amplitude %d' % (peak0_pos, peak0_max))
    print('Total width in samples is %d' % (peak0_right_samples - peak0_left_samples))
    return peak0_fwhm

# %%
print(get_peak_properties(0, 700, bin_counts, bin_edges))
print(get_peak_properties(700, 1000, bin_counts, bin_edges))
# Out:
# Returning properties of peak found at 219.5 amplitude 225
# Total width in samples is 18
# 1.64009111617
# Returning properties of peak found at 278.1 amplitude 223
# Total width in samples is 18
# 1.29449838188

# %%
df_0 = df[(df['amp'] > 205) & (df['amp'] < 230)]
df_1 = df[(df['amp'] > 265) & (df['amp'] < 290)]
print('Events in windows: %d (%.1f %%) and %d (%.1f %%)' % (len(df_0), 100*len(df_0)/len(df),
                                                        len(df_1), 100*len(df_1)/len(df)))
# Out:
# Events in windows: 3986 (34.1 %) and 4372 (37.4 %)

# %%
plt.hist(df_0['time'], histtype='step', bins=40, range=(0, 8000))
plt.hist(df_1['time'], histtype='step', bins=40, range=(0, 8000))
plt.yticks()
plt.show()

# %% [markdown]
# ### Write mongo tag

# %%
client = MongoClient()
runs_db = client['run']
runs = runs_db['runs']

# %%
run_docs_to_do = list(runs.find({'name' : '180327_030021'}))

# %%
run_docs_to_do[0]
# Out:
# {'_id': ObjectId('5ab9b3c6c9020843308cf45a'),
#  'comment': '',
#  'ini': {'baseline_mode': 0,
#   'blt_size': 524288,
#   'boards': [{'crate': 0,
#     'link': 0,
#     'reader': 0,
#     'serial': '077',
#     'type': 'V1724',
#     'vme_address': 'Whatever?'}],
#   'comments': '143 degrees AmBe to EJ, full shielding on TPC and EJ, AmBe, EJ 1560V, half hour resets of the anode, 15 mV coincidence trigger, liquid level -2 mm',
#   'compression': 1,
#   'data_folder': '/home/xams/lena/run9/raw/data',
#   'delete_data': True,
#   'do_not_process': False,
#   'ini_template_name': 'EJ_passive',
#   'lena_pax_config_path': '/data/xenon/xams/run9/pax_ini/XAMS_raw_to_processed_EJ.ini',
#   'links': [{'crate': 0, 'link': 0, 'reader': 0, 'type': 'V2718'}],
#   'mongo': {'address': 'mongodb://localhost:27017',
#    'collection': '180327_030021',
#    'database': 'xamsdata0',
#    'min_insert_size': 1,
#    'write_concern': 0},
#   'occurrence_integral': 0,
#   'processing_mode': 3,
#   'processing_num_threads': 8,
#   'processing_readout_threshold': 0,
#   'registers': [{'board': '-1',
#     'comment': 'Reset software (all registers)',
#     'register': 'EF24',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'BLT event number',
#     'register': 'EF1C',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'Enable BERR (error messages)',
#     'register': 'EF00',
#     'value': '10'},
#    {'board': '-1',
#     'comment': 'Aquisition control register',
#     'register': '8100',
#     'value': '5'},
#    {'board': '-1',
#     'comment': 'Channel calibration',
#     'register': '809C',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'Channel enable mask',
#     'register': '8120',
#     'value': '19'},
#    {'board': '-1',
#     'comment': 'Measurement time after trigger',
#     'register': '8114',
#     'value': '1400'},
#    {'board': '-1',
#     'comment': 'Trigger source enable mask',
#     'register': '810C',
#     'value': 'C1F00003'},
#    {'board': '-1',
#     'comment': 'Buffer organisation',
#     'register': '800C',
#     'value': '6'},
#    {'board': '-1',
#     'comment': 'Interrupt status ID',
#     'register': 'EF14',
#     'value': '55AA'},
#    {'board': '-1',
#     'comment': 'Interrupt event number',
#     'register': 'EF18',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'Channel 0 gain',
#     'register': '1028',
#     'value': '0'},
#    {'board': '-1',
#     'comment': 'Channel 3 gain',
#     'register': '1328',
#     'value': '0'},
#    {'board': '-1',
#     'comment': 'Trigger level channel 0',
#     'register': '1080',
#     'value': '1f86'},
#    {'board': '-1',
#     'comment': 'Trigger level channel 3',
#     'register': '1380',
#     'value': '1fc7'},
#    {'board': '-1',
#     'comment': 'Trigger polarity',
#     'register': '8000',
#     'value': '40'}],
#   'run_start': 0,
#   'super_zle': False,
#   'write_mode': 2,
#   'zle': True},
#  'name': '180327_030021',
#  'start': datetime.datetime(2018, 3, 27, 3, 0, 22)}

# %%
import datetime

# %%
runs.find_one_and_update({'name': '180327_030021'},
                                                {'$set': {
                    'end': datetime.datetime(2018, 3, 27, 3, 0, 22)}})
# Out:
# {'_id': ObjectId('5ab9b3c6c9020843308cf45a'),
#  'comment': '',
#  'ini': {'baseline_mode': 0,
#   'blt_size': 524288,
#   'boards': [{'crate': 0,
#     'link': 0,
#     'reader': 0,
#     'serial': '077',
#     'type': 'V1724',
#     'vme_address': 'Whatever?'}],
#   'comments': '143 degrees AmBe to EJ, full shielding on TPC and EJ, AmBe, EJ 1560V, half hour resets of the anode, 15 mV coincidence trigger, liquid level -2 mm',
#   'compression': 1,
#   'data_folder': '/home/xams/lena/run9/raw/data',
#   'delete_data': True,
#   'do_not_process': False,
#   'ini_template_name': 'EJ_passive',
#   'lena_pax_config_path': '/data/xenon/xams/run9/pax_ini/XAMS_raw_to_processed_EJ.ini',
#   'links': [{'crate': 0, 'link': 0, 'reader': 0, 'type': 'V2718'}],
#   'mongo': {'address': 'mongodb://localhost:27017',
#    'collection': '180327_030021',
#    'database': 'xamsdata0',
#    'min_insert_size': 1,
#    'write_concern': 0},
#   'occurrence_integral': 0,
#   'processing_mode': 3,
#   'processing_num_threads': 8,
#   'processing_readout_threshold': 0,
#   'registers': [{'board': '-1',
#     'comment': 'Reset software (all registers)',
#     'register': 'EF24',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'BLT event number',
#     'register': 'EF1C',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'Enable BERR (error messages)',
#     'register': 'EF00',
#     'value': '10'},
#    {'board': '-1',
#     'comment': 'Aquisition control register',
#     'register': '8100',
#     'value': '5'},
#    {'board': '-1',
#     'comment': 'Channel calibration',
#     'register': '809C',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'Channel enable mask',
#     'register': '8120',
#     'value': '19'},
#    {'board': '-1',
#     'comment': 'Measurement time after trigger',
#     'register': '8114',
#     'value': '1400'},
#    {'board': '-1',
#     'comment': 'Trigger source enable mask',
#     'register': '810C',
#     'value': 'C1F00003'},
#    {'board': '-1',
#     'comment': 'Buffer organisation',
#     'register': '800C',
#     'value': '6'},
#    {'board': '-1',
#     'comment': 'Interrupt status ID',
#     'register': 'EF14',
#     'value': '55AA'},
#    {'board': '-1',
#     'comment': 'Interrupt event number',
#     'register': 'EF18',
#     'value': '1'},
#    {'board': '-1',
#     'comment': 'Channel 0 gain',
#     'register': '1028',
#     'value': '0'},
#    {'board': '-1',
#     'comment': 'Channel 3 gain',
#     'register': '1328',
#     'value': '0'},
#    {'board': '-1',
#     'comment': 'Trigger level channel 0',
#     'register': '1080',
#     'value': '1f86'},
#    {'board': '-1',
#     'comment': 'Trigger level channel 3',
#     'register': '1380',
#     'value': '1fc7'},
#    {'board': '-1',
#     'comment': 'Trigger polarity',
#     'register': '8000',
#     'value': '40'}],
#   'run_start': 0,
#   'super_zle': False,
#   'write_mode': 2,
#   'zle': True},
#  'name': '180327_030021',
#  'start': datetime.datetime(2018, 3, 27, 3, 0, 22)}

# %%
collname = 'runs'

# %%
cursor = client[dbname][collname].find()
for i, doc in enumerate(cursor):
    if i == 593:
        print(doc['start'])
# Out:
# 2018-03-27 03:00:22
