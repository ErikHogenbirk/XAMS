# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import math

# %%
voltage = [750, 775, 800, 825, 850]
gain1 = [0.5, 0.83, 1.33, 1.99, 2.94]
gain2 = [0.51, 0.62 ,0.76, 1.09, 1.69]
plt.plot(voltage, gain1, marker = '.', markersize = 10)
plt.plot(voltage, gain2, marker = '.', markersize = 10)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### Kopje

# %% [markdown]
# markdown ipython
