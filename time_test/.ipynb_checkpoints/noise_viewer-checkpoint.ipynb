# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from scipy.optimize import curve_fit
# %matplotlib inline
import os

# %%
np.loadtxt?

# %%
filename = '/home/xams/xams/time_test/Event.txt'
    
data = np.loadtxt(filename, delimiter="\t", dtype=float, usecols=[0,18,19])

# %%
evt_n = data[:,0]
start_times = data[:,1]
stop_times = data[:,2]

# %%
# One time unit equals 400 ns!
0.01/np.average(np.diff(start_times))
# Out:
# 4.0000215176280267e-09

# %%
plt.hist(np.diff(start_times), bins=400, range=(0, 1e7))
plt.show()

# %%
plt.plot(start_times*4e-9, evt_n)

# %%
float(4e-7)
# Out:
# 4e-07

# %%
plt.scatter(data0['area'], data0['noise_sigma_adc'], edgecolor = 'none', s=10, alpha = 0.2)
# plt.xscale('log')
# plt.yscale('log')
plt.xlabel("Area (electrons)")
plt.ylabel("baseline (counts)")
plt.grid(alpha=0.2, linestyle='-')
plt.ylim([0,20])
plt.xlim([-1e7, 1.5e7])
plt.show()
