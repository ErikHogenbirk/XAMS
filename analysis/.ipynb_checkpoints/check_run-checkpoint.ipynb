# %% [markdown]
# ## Quick check analysis notebook

# %% [markdown]
# ### Imports

# %%
# %run definitions.ipynb

# %% [markdown]
# ### Configuration

# %%
processed_data_path = '/home/xams/lena/run8/processed/data/'
minitree_path = '/home/xams/lena/run8/minitrees/'

# %%
run_names = get_run_list(processed_data_path, 
                         start_at = '170317_121520', stop_at = '170317_151620')
# run_names = ['170316_122219imp', '170316_125829imp', '170316_130849imp', '170316_131359', '170316_132742imp', '170316_134312imp']
# run_names.append('170317_134550')

# run_names = ['170317_121520imp']
# Out:
# Run list contains 7 files

# %%
hax.init(
    # Always use these lines to tell hax that we don't care about Xe1T
    experiment='XAMS', 
    pax_version_policy='loose', use_runs_db = False,
    # Here come the useful settings
    main_data_paths = [processed_data_path],
    minitree_paths = [minitree_path],
    # raw_data_local_path = raw_data_path         
         )
# Out:
# INFO:hax.__init__] Not looking for datasets in runs db since you put use_runs_db = False
# WARNING:hax.__init__] You're not at a XENON analysis facility, or hax can't detect at which analysis facility you are.

# %%
d = hax.minitrees.load(run_names, ['Fundamentals', XAMSProperties], 
                       num_workers =4)
d = get_time(d, run_names)
print('Loaded %d events.' % len(d))
# Out:
# Could not find run number for 170317_131540, got exception <class 'KeyError'>: 'number'. Setting run number to 0.
# Could not find run number for 170317_141600, got exception <class 'KeyError'>: 'number'. Setting run number to 0.
# Could not find run number for 170317_144610, got exception <class 'KeyError'>: 'number'. Setting run number to 0.
# Run 170317_144610: Making Fundamentals minitree:   0%|          | 0/48265 [00:00<?, ?it/s]
# Could not find run number for 170317_151620, got exception <class 'KeyError'>: 'number'. Setting run number to 0.
# ...
# Run 170317_151620: Making Fundamentals minitree:  21%|██        | 16163/78651 [00:06<6:22:36,  2.72it/s]
# Could not find run number for 170317_144610, got exception <class 'KeyError'>: 'number'. Setting run number to 0.
# ...
# Run 170317_141600: Making Fundamentals minitree:  95%|█████████▌| 66836/70299 [00:08<00:13, 247.82it/s]]
# ...

# %% [markdown]
# ### Elementary cuts and plots

# %%
d = cuts.isfinite(d, 's1_area')
# Out:
# Finite s1_area selection: 19706 rows removed (93.50% passed)

# %%
plt.hist2d(d['time_since_start']/3600, np.log10(d['s1_area']), 
          bins=(100, 100), norm=LogNorm(), range=((0,5),(0,5)))
plt.ylabel('log10 S1 area')
plt.axhline(3.7)
plt.show()

# %%
plt.hist(d['s2_n_saturated_channels'], range=(0,2), bins=3)
plt.show()

# %%
d = cuts.isfinite(d, 's2_area')
d = cuts.above(d, 'drift_time', 0)
# Out:
# Finite s2_area selection: 95885 rows removed (66.16% passed)
# drift_time above 0 selection: 5517 rows removed (97.06% passed)

# %%
plt.hist2d(d['time_since_start']/3600, np.log10(d['s2_area']), 
           bins=(100), norm=LogNorm(), range=((0,5), (0,6)))
plt.ylabel('log10 S2 area')
plt.xlabel('Time since run start (h)')
plt.axhline(5)
plt.axhline(4.7)
plt.axvline(3.5)
plt.axvline(6)
plt.savefig('170316_BG_S2_area_over_time_Na22_burst_at_1h5', bboxinches = 'tight')
#plt.xlim(0.7, 3.5)
plt.show()

# %%
plt.hist(d['time_since_start']/3600, bins=400, histtype='step')
plt.show()

# %%
plt.hist2d(d['time_since_start']/3600, (d['s2_range_50p_area'])*1e-3, 
           bins=(80), norm=LogNorm(), range=((0,3), (0,1)))
plt.ylabel('S2 width')
plt.xlabel('Time since run start (h)')
# plt.savefig('170314_field_dependent_width.png', bbox_inches='tight')
plt.show()

# %%
plt.hist2d(d['time_since_start'], d['s2_area'], 
           bins=(80), norm=LogNorm(), range=((0,7200), (0,150000)))
plt.ylabel('log10 S2 area')
plt.xlabel('Time since run start (s)')
plt.axhline(63000)
plt.show()

# %% [markdown]
# ### Select the good part

# %%
d = d[(d['time_since_start']/3600. < 2.4)]

# %% [markdown]
# ### Drift time analysis

# %%
plt.hist2d(d['drift_time'] * 1e-3, np.log10(d['s2_area']), bins=100, norm=LogNorm(), range = ((0,70),(0,6)))
x_plot = np.linspace(0,80, 10)
def exp(x, a0, tau):
    return a0*np.exp(-x/tau)
plt.plot(x_plot, exp(x_plot, 65000, 1000))
#plt.axhline(64000)
plt.show()

# %%
limits = (20e3, 50e3)

plt.hist(d['drift_time'] * 1e-3, bins=100, range=(0,70), 
         histtype='step', normed=True)
# plt.hist(d_cut['drift_time'] * 1e-3, bins=100, range=(0,70), 
#          histtype='step', normed=True)
plt.axvline(limits[0]*1e-3)
plt.axvline(limits[1]*1e-3)
d_cut = cuts.range_selection(d, 'drift_time', limits)
plt.show()
# Out:
# drift_time in [20000.0, 50000.0) selection: 59965 rows removed (47.40% passed)

# %%
d_cut = cuts.range_selection(d, 'drift_time', limits)
# Out:
# drift_time in [20000.0, 50000.0) selection: 59965 rows removed (47.40% passed)

# %%
plt.hist2d(d['drift_time'] * 1e-3, d['s1_area'], bins=100, 
           norm=LogNorm(), range = ((0,70),(0,2000)))

plt.plot(x_plot, np.log10(exp(x_plot, 10**3.8, 300)))
# plt.axhline(3.8)
plt.show()

# %% [markdown]
# ### Electron lifetime & correction

# %%
d['s2_area_crappycorr'] = (d['s2_area'] * 
                              np.exp(d['drift_time']*1e-3 / 300))

# %%
plt.hist2d(d['drift_time'] * 1e-3, np.log10(d['s2_area']), bins=100, norm=LogNorm(),
          )
x_plot = np.linspace(0,80, 10)
def exp(x, a0, tau):
    return a0*np.exp(-x/tau)
#plt.plot(x_plot, np.log10(exp(x_plot, 10**3.8, 22)))
plt.axhline(3.8)
plt.show()

# %% [markdown]
# ### Saturation check

# %%
a = plt.hist(d['s1_n_saturated_channels'], range=(0,2), bins=3, color = 'red')
# plt.yscale('log')
plt.show()
print(a[0])
b = plt.hist(d['s2_n_saturated_channels'], range=(0,2), bins=3)
# plt.yscale('log')
plt.show()
print(b[0])
# Out:
# [ 103397.   10402.     207.]
# [ 102656.    1918.    9432.]

# %%
plt.hist(d_cut['s1_area'], bins=400, histtype='step', range=(0, 5000))
plt.hist(d_cut[d_cut['s1_n_saturated_channels'] > 0]['s1_area'], 
         bins=400, histtype='step', range=(0, 5000))
plt.show()

# %% [markdown]
# ### S1S2 scatter

# %%
len(d_cut)
# Out:
# 54041

# %%
len(d)
# Out:
# 114006

# %%
plt.scatter(d_cut['s1_area'], d_cut['s2_area']*1e-3, 
            edgecolor='None', marker = '.', s=10, c=d_cut['largest_other_s2'] / d_cut['s2_area'], vmax=0.05
           )
plt.xlabel('S1 (p.e.)')
plt.ylabel('S2 (x10$^3$ p.e.)')
plt.xlim(0,200)
plt.ylim(0,4)
plt.colorbar()
# plt.savefig('170317_neutron_faraway.png')
plt.show()

# %%
plt.hist2d(d_cut['s1_area'], d_cut['s2_area']*1e-3, 
           bins=120, 
           norm=LogNorm(),
           range=((0, 150), (0, 4)))
plt.xlabel('S1 (p.e.)')
plt.ylabel('S2 (x10$^3$ p.e.)')
plt.colorbar()

plt.show()

# %%
plt.scatter(d['s1_area'], d['s2_area']*1e-3, edgecolor = 'None',
           marker='.', s=20, c=d['s1_center_time']*1e-3, vmax=80, vmin=70)
plt.axhline(0.040)
plt.colorbar()
plt.xlim(0,20)
plt.ylim(0,1)
plt.show()

# %%
plt.hist(d[d['s1_area']<100]['s1_center_time']*1e-3, bins=100)
#plt.yscale('log')
plt.show()

# %%
_d = cuts.range_selection(d_cut, 's1_area', (200,300))
# Out:
# s1_area in [200, 300) selection: 5582 rows removed (2.97% passed)

# %%
plt.hist2d(d['s2_area']*1e-3, d['s2_area_fraction_top'],
           bins=80, range=((0,1),(0,1)))
plt.axhline(0.58, color='white')
plt.show()

# %%
plt.hist2d(d['s2_area']*1e-3, d['s2_range_50p_area']*1e-3,
           bins=80, range=((0,20),(0,1)))
plt.axhline(0.4, color='white')
plt.show()

# %%
plt.hist2d(d['drift_time'], d['s1_area_fraction_top'], bins=100, norm=LogNorm())
plt.show()

# %%
plt.hist2d(d['drift_time'], d['s2_range_50p_area'], 
           bins=100, norm=LogNorm(), range=((0,60000), (0,1000)))
plt.show()

# %%
d_cut2 = cuts.above(d_cut, 's2_range_50p_area', 0.4 * 1e3)
d_cut2 = cuts.below(d_cut2, 's2_area_fraction_top', 0.58)

plt.hist2d(d_cut2['s1_area'], d_cut2['s2_area']*1e-3, 
           bins=80, 
           norm=LogNorm(), range=((0,100), (0, 5)))
plt.colorbar()
plt.show()
# Out:
# s2_range_50p_area above 400.0 selection: 544 rows removed (92.00% passed)
# s2_area_fraction_top below 0.58 selection: 39 rows removed (99.38% passed)

# %%
d_cut2 = cuts.above(d_cut, 's2_range_50p_area', 0.4 * 1e3)
d_cut2 = cuts.below(d_cut2, 's2_area_fraction_top', 0.58)

plt.hist2d(d_cut2['s1_area'], d_cut2['s2_area']*1e-3, 
           bins=80, 
           norm=LogNorm(), range=((0,100), (0, 5)))
plt.colorbar()
plt.show()
# Out:
# s2_range_50p_area above 400.0 selection: 336 rows removed (94.16% passed)
# s2_area_fraction_top below 0.58 selection: 63 rows removed (98.84% passed)

# %%
plt.scatter(d_cs['s1_area'], d_cs['s2_area']*1e-3, 
            edgecolor='none', s=3, alpha=0.5, c=d_cs['largest_other_s2'],
           vmax=1000)
plt.colorbar()
plt.xlim(0,2000)
plt.ylim(0,100)
# Out:
# (0, 100)

# %%
d_cs = cuts.below(d_cs, 'largest_other_s2', 1000)
# Out:
# largest_other_s2 below 1000 selection: 229 rows removed (87.36% passed)

# %%
plt.hist2d(d_cs['s1_area'], d_cs['s2_area']*1e-3, bins=80, 
           norm=LogNorm(), range=((0,600), (0, 100)))
plt.xlabel('S1 (uncalibrated)')
plt.ylabel('S2 (uncalibrated)')
plt.title('Na-22, from 6 to 6.,5 hour')
plt.savefig('170310_s1s2_na22.png', bbox_inches='tight')
plt.show()

# %%
3.14*4**2/(4*3.14*50**2)*1200
# Out:
# 1.9200000000000002
