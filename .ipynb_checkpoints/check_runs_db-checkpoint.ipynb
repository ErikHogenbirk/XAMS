# %%
import pytz
import time
import os
import pymongo
from pax import core

client = pymongo.MongoClient()
runs_collection = client['run']['runs']

pax_ini_config_path = '/home/xams/xams/PMT12_gain/daq_to_raw_PMT12_gain.ini'
data_directory = '/home/xams/xams/PMT12_gain/K_series/'
done_field_name = 'event_building_complete'

# %%
#Hard coding to set processing to done
def set_as_processed(name):
    runs_collection.find_one_and_update({'name': name},
                                   {'$set': {done_field_name: True}})

# %%
runs = list(runs_collection.find())
run_doc = runs[0]

# %%
with open(os.path.join('/home/xams/', 'run_db_backup_170202.pkl'), mode='wb') as outfile:
    #pickle.dump(run_doc, outfile)
    pickle.dump(runs, outfile)

# %%
from prettytable import PrettyTable
run_doc_human = run_doc.copy()
run_doc_human_ini = run_doc_human['ini']
for key, val in run_doc_human_ini.items():
    run_doc_human['ini_' + key] = val
for reg_dict in run_doc_human_ini['registers']:
    run_doc_human['ini_registers_' + reg_dict['register']] = reg_dict
del(run_doc_human['ini'])
del(run_doc_human['ini_registers'])

t = PrettyTable(['key', 'value'])
for key, val in sorted(run_doc_human.items()):
   t.add_row([key, val])
t.align = "l"
with open('/home/xams/blabla.txt', 'w') as f:
    f.write(str(t))

# %%
import numpy as np
np.sort(list(run_doc_human.keys()))
# Out:
# array(['_id', 'comment', 'end', 'event_building_complete',
#        'ini_baseline_mode', 'ini_blt_size', 'ini_boards',
#        'ini_compression', 'ini_links', 'ini_mongo',
#        'ini_occurrence_integral', 'ini_processing_mode',
#        'ini_processing_num_threads', 'ini_processing_readout_threshold',
#        'ini_registers_1028', 'ini_registers_1080', 'ini_registers_1328',
#        'ini_registers_1380', 'ini_registers_1428', 'ini_registers_1480',
#        'ini_registers_8000', 'ini_registers_800C', 'ini_registers_8020',
#        'ini_registers_809C', 'ini_registers_8100', 'ini_registers_810C',
#        'ini_registers_8114', 'ini_registers_8120', 'ini_registers_EF00',
#        'ini_registers_EF14', 'ini_registers_EF18', 'ini_registers_EF1C',
#        'ini_registers_EF24', 'ini_run_start', 'ini_write_mode', 'name',
#        'start'],
#       dtype='<U32')

# %%
t = PrettyTable(['key', 'value'])
for key, val in sortedrun_doc_human.items()):
   t.add_row([key, val])
with open('/home/xams/blabla.txt', 'w') as f:
    f.write(str(t))

# %%
import json
import pickle
with open(os.path.join('/home/xams/', 'run_doc.pkl'), mode='w') as outfile:
    #pickle.dump(run_doc, outfile)
    json.dump(run_doc, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-df804ae13934> in <module>()
#       3 with open(os.path.join('/home/xams/', 'run_doc.pkl'), mode='w') as outfile:
#       4     #pickle.dump(run_doc, outfile)
# ----> 5     json.dump(run_doc, outfile)
#
# /home/xams/anaconda3/envs/pax/lib/python3.4/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     176     # could accelerate with writelines in some versions of Python, at
#     177     # a debuggability cost
# --> 178     for chunk in iterable:
#     179         fp.write(chunk)
#     180
#
# /home/xams/anaconda3/envs/pax/lib/python3.4/json/encoder.py in _iterencode(o, _current_indent_level)
#     420             yield from _iterencode_list(o, _current_indent_level)
#     421         elif isinstance(o, dict):
# --> 422             yield from _iterencode_dict(o, _current_indent_level)
#     423         else:
#     424             if markers is not None:
#
# /home/xams/anaconda3/envs/pax/lib/python3.4/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     394                 else:
#     395                     chunks = _iterencode(value, _current_indent_level)
# --> 396                 yield from chunks
#     397         if newline_indent is not None:
#     398             _current_indent_level -= 1
#
# /home/xams/anaconda3/envs/pax/lib/python3.4/json/encoder.py in _iterencode(o, _current_indent_level)
#     427                     raise ValueError("Circular reference detected")
#     428                 markers[markerid] = o
# --> 429             o = _default(o)
#     430             yield from _iterencode(o, _current_indent_level)
#     431             if markers is not None:
#
# /home/xams/anaconda3/envs/pax/lib/python3.4/json/encoder.py in default(self, o)
#     171
#     172         """
# --> 173         raise TypeError(repr(o) + " is not JSON serializable")
#     174
#     175     def encode(self, o):
#
# TypeError: datetime.datetime(2017, 2, 1, 10, 7, 10) is not JSON serializable

# %%
pickle.load(
    open('/home/xams/xams/pmtdata/170202_104333/run_doc.pkl', 'rb')),
# Out:
# ({'_id': ObjectId('58930d55f031497c986d19f7'),
#   'comment': '',
#   'ini': {'baseline_mode': 0,
#    'blt_size': 524288,
#    'boards': [{'crate': 0,
#      'link': 0,
#      'reader': 0,
#      'serial': '077',
#      'type': 'V1724',
#      'vme_address': 'Whatever?'}],
#    'comments': '\r\n',
#    'compression': 1,
#    'data_folder': '/home/xams/xams/pmtdata',
#    'delete_data': False,
#    'ini_template_name': 'PMTcal',
#    'links': [{'crate': 0, 'link': 0, 'reader': 0, 'type': 'V2718'}],
#    'mongo': {'address': 'mongodb://localhost:27017',
#     'collection': '170202_104333',
#     'database': 'xamsdata0',
#     'min_insert_size': 1,
#     'write_concern': 0},
#    'occurrence_integral': 0,
#    'processing_mode': 3,
#    'processing_num_threads': 8,
#    'processing_readout_threshold': 0,
#    'registers': [{'board': '-1',
#      'comment': 'Reset software (all registers)',
#      'register': 'EF24',
#      'value': '1'},
#     {'board': '-1',
#      'comment': 'BLT event number',
#      'register': 'EF1C',
#      'value': '40'},
#     {'board': '-1',
#      'comment': 'Enable BERR (error messages)',
#      'register': 'EF00',
#      'value': '10'},
#     {'board': '-1',
#      'comment': 'Aquisition control register',
#      'register': '8100',
#      'value': '5'},
#     {'board': '-1',
#      'comment': 'Channel calibration',
#      'register': '809C',
#      'value': '1'},
#     {'board': '-1',
#      'comment': 'Channel enable mask',
#      'register': '8120',
#      'value': '09'},
#     {'board': '-1',
#      'comment': 'Measurement time after trigger',
#      'register': '8114',
#      'value': '20'},
#     {'board': '-1',
#      'comment': 'Trigger source enable mask',
#      'register': '810C',
#      'value': 'C0000004'},
#     {'board': '-1',
#      'comment': 'Buffer organisation',
#      'register': '800C',
#      'value': 'A'},
#     {'board': '-1',
#      'comment': 'Interrupt status ID',
#      'register': 'EF14',
#      'value': '55AA'},
#     {'board': '-1',
#      'comment': 'Interrupt event number',
#      'register': 'EF18',
#      'value': '1'},
#     {'board': '-1',
#      'comment': 'Channel 0 gain',
#      'register': '1028',
#      'value': '1'},
#     {'board': '-1',
#      'comment': 'Channel 3 gain',
#      'register': '1328',
#      'value': '1'},
#     {'board': '-1',
#      'comment': 'Channel 4 gain',
#      'register': '1428',
#      'value': '0'},
#     {'board': '-1',
#      'comment': 'Trigger level channel 0',
#      'register': '1080',
#      'value': '0000'},
#     {'board': '-1',
#      'comment': 'Trigger level channel 3',
#      'register': '1380',
#      'value': '0000'},
#     {'board': '-1',
#      'comment': 'Trigger level channel 4',
#      'register': '1480',
#      'value': '1770'},
#     {'board': '-1',
#      'comment': 'Trigger polarity',
#      'register': '8000',
#      'value': '40'},
#     {'board': '-1',
#      'comment': 'Set event window size',
#      'register': '8020',
#      'value': '40'}],
#    'run_start': 0,
#    'write_mode': 2},
#   'name': '170202_104333',
#   'start': datetime.datetime(2017, 2, 2, 10, 43, 33)},)

# %%
try:
    register_list = runs[0]['ini']['registers']
    channels_enabled_dict = next(item for item in register_list if item["register"] == "8120")
    channels_enabled_str = channels_enabled_dict['value']
    binary_string = bin(int(channels_enabled_str, 16))[2:]
    channel_enabled_list = [ch_n for ch_n, enabled in enumerate(reversed(binary_string)) if enabled=='1']
except:
    print('WARNING did not correctly read channel enable mask, using [0,3]...')
    channel_enabled_list = [0,3]

# %%
channels_enabled_str
# Out:
# '09'

# %%
(runs[0]['end'] - runs[0]['start']).total_seconds() / 60
# Out:
# 4.0

# %%
import datetime
datetime.datetime.utcnow().strftime('%y%m%d_%H%M%S')
# Out:
# '170201_144239'

# %%
while True:
    # Get all runs for which events have not been built yet
    runs_todo = list(runs_collection.find({done_field_name: {'$exists': False}}))
    print("%d runs to do" % len(runs_todo))
    
    if not runs_todo:
        print("No more runs to process, waiting a while...")
        time.sleep(10)
        continue
    
    for run_doc in runs_todo:
        _id = run_doc['_id']
        
        # Create a timestamp-based run label, which we use to name the output folder
        # Ideally kodiaq would already do this
        run_label = run_doc['name'] + '_' + run_doc['start'].strftime('%y%m%d_%H%M%S')
        
        # Get possible pax config overrides from the run doc
        conf_override = run_doc.get('pax_config', {})
        
        # Set the input (mongo collection) and output ()
        conf_override.setdefault('pax', {})
        conf_override['pax']['input_name'] = str(_id)
        conf_override['pax']['output_name'] = os.path.join(data_directory, run_label)
        
        # WARNING this will delete your data!
        conf_override.setdefault('MongoXAMS', {})
        conf_override['MongoXAMS']['delete_data'] = False
        
        print("Starting pax to process run %s" % _id)
        mypax = core.Processor(config_paths=pax_ini_config_path,
                               config_dict=conf_override)
        mypax.run()
        del mypax
        print("Pax is done!")
        
        runs_collection.find_one_and_update({'_id': _id}, {'$set': {done_field_name: True}})
        
        print("Temporary nap to prevent infinite print or something")
        time.sleep(3)
# Out:
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# 1 runs to do
# Starting pax to process run 5891b25e9b6d0110c5cf2a39
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0900_170201_100310
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 377120477.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 25434 pulses
# xamsdata0
# 5891b25e9b6d0110c5cf2a39
# 1 hi
# 45600
# Event: 25318it [00:08, 2949.81it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 377120477.000 mongos until 1487901517.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 74912 pulses
# Event: 100208it [00:35, 2578.54it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 1487901517.000 mongos until 4795044129.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 223020 pulses
# Event: 323182it [01:54, 2679.35it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 4795044129.000 mongos until 14676967219.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 666286 pulses
# Event: 989364it [05:32, 3401.99it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 14676967219.000 mongos until 30044338297.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 1035790 pulses
# Event: 2025442it [10:49, 3118.43it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  29.6 |         0.1 |        |     192.0 |
# | EncodeZPickle      |  51.8 |         0.2 |        |     336.5 |
# | WriteZipped        |  18.6 |         0.1 |        |     121.0 |
# | TOTAL              | 100.0 |         0.3 | 3118.4 |     649.5 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K1000_170201_104000
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 862599055.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 58114 pulses
# 1 runs to do
# Starting pax to process run 5891bb0010ac376b240a71a7
# xamsdata0
# 5891bb0010ac376b240a71a7
# 2 hi
# 78270
# Event: 57816it [00:20, 2810.78it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 862599055.000 mongos until 3412949359.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 171814 pulses
# Event: 229733it [01:18, 3475.09it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 3412949359.000 mongos until 9338476245.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 399112 pulses
# Event: 629040it [03:16, 3197.86it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  29.5 |         0.1 |        |      58.0 |
# | EncodeZPickle      |  52.0 |         0.2 |        |     102.2 |
# | WriteZipped        |  18.5 |         0.1 |        |      36.5 |
# | TOTAL              | 100.0 |         0.3 | 3197.8 |     196.7 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K1000actual_170201_104425
# 1 runs to do
# Starting pax to process run 5891bc09d360be70c223c00c
# xamsdata0
# 5891bc09d360be70c223c00c
# 3 hi
# 30912
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L151 INFO Insufficient data remaining, sleeping 6.4 sec, then retrying
# MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 960054845.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 64652 pulses
# Event: 64437it [00:28, 2931.74it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 960054845.000 mongos until 3752755191.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 188084 pulses
# Event: 252444it [01:32, 3045.48it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 3752755191.000 mongos until 11702795995.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 535464 pulses
# Event: 788160it [04:29, 3529.77it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 11702795995.000 mongos until 30237363983.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 1248408 pulses
# Event: 2036608it [11:20, 2991.77it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  31.5 |         0.1 |        |     214.2 |
# | EncodeZPickle      |  50.3 |         0.2 |        |     342.6 |
# | WriteZipped        |  18.2 |         0.1 |        |     123.9 |
# | TOTAL              | 100.0 |         0.3 | 2991.8 |     680.7 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# 2 runs to do
# Starting pax to process run 5891bd44cb61311c57ad470b
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0975_170201_104940
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 30039767577.0000 mongos
# xamsdata0
# 5891bd44cb61311c57ad470b
# 5 hi
# 2023654
# MongoDBInputOnline MainProcess L160 INFO Found 2023654 pulses
# Event: 2023654it [10:46, 3128.25it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  30.9 |         0.1 |        |     199.9 |
# | EncodeZPickle      |  51.0 |         0.2 |        |     330.0 |
# | WriteZipped        |  18.1 |         0.1 |        |     117.0 |
# | TOTAL              | 100.0 |         0.3 | 3128.2 |     646.9 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# Starting pax to process run 5891be8e1e97294c4ba7d42e
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0950_170201_105510
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 30054436303.0000 mongos
# xamsdata0
# 5891be8e1e97294c4ba7d42e
# 5 hi
# 2024490
# MongoDBInputOnline MainProcess L160 INFO Found 2024490 pulses
# Event: 2024490it [10:28, 3218.72it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  30.5 |         0.1 |        |     191.9 |
# | EncodeZPickle      |  51.3 |         0.2 |        |     322.6 |
# | WriteZipped        |  18.2 |         0.1 |        |     114.5 |
# | TOTAL              | 100.0 |         0.3 | 3218.7 |     629.0 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# 1 runs to do
# Starting pax to process run 5891ce01706e5640d0c90e9b
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0925_170201_120105
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L151 INFO Insufficient data remaining, sleeping 6.9 sec, then retrying
# xamsdata0
# 5891ce01706e5640d0c90e9b
# 6 hi
# 27842
# MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 972778519.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 65882 pulses
# Event: 65676it [00:30, 2839.49it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 972778519.000 mongos until 3901161291.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 198230 pulses
# Event: 263875it [01:40, 2947.61it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 3901161291.000 mongos until 12731921487.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 597206 pulses
# Event: 861301it [05:01, 3529.76it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 12731921487.000 mongos until 30137834945.0000 mongos
# MongoDBInputOnline MainProcess L160 INFO Found 1175134 pulses
# Event: 2036452it [11:42, 2899.08it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  31.5 |         0.1 |        |     221.4 |
# | EncodeZPickle      |  50.5 |         0.2 |        |     354.6 |
# | WriteZipped        |  18.0 |         0.1 |        |     126.5 |
# | TOTAL              | 100.0 |         0.3 | 2899.0 |     702.5 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# 2 runs to do
# Starting pax to process run 5891cf553912ee024a9dc850
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0875_170201_120645
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 29980258303.0000 mongos
# xamsdata0
# 5891cf553912ee024a9dc850
# 8 hi
# 2020930
# MongoDBInputOnline MainProcess L160 INFO Found 2020930 pulses
# Event: 2020930it [11:03, 3044.74it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  31.1 |         0.1 |        |     206.1 |
# | EncodeZPickle      |  50.8 |         0.2 |        |     336.9 |
# | WriteZipped        |  18.2 |         0.1 |        |     120.8 |
# | TOTAL              | 100.0 |         0.3 | 3044.7 |     663.7 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# Starting pax to process run 5891d090a892122a03661d9b
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0850_170201_121200
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 30011664859.0000 mongos
# xamsdata0
# 5891d090a892122a03661d9b
# 10 hi
# 2021820
# MongoDBInputOnline MainProcess L160 INFO Found 2021820 pulses
# Event: 2021820it [11:15, 2990.89it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  31.2 |         0.1 |        |     210.9 |
# | EncodeZPickle      |  50.7 |         0.2 |        |     342.5 |
# | WriteZipped        |  18.1 |         0.1 |        |     122.6 |
# | TOTAL              | 100.0 |         0.3 | 2990.9 |     676.0 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# 4 runs to do
# Starting pax to process run 5891d20ce223d35520a93f91
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0825_170201_121820
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 30003484295.0000 mongos
# xamsdata0
# 5891d20ce223d35520a93f91
# 12 hi
# 2020812
# MongoDBInputOnline MainProcess L160 INFO Found 2020812 pulses
# Event: 2020812it [10:38, 3164.34it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  30.7 |         0.1 |        |     196.4 |
# | EncodeZPickle      |  51.0 |         0.2 |        |     326.0 |
# | WriteZipped        |  18.2 |         0.1 |        |     116.3 |
# | TOTAL              | 100.0 |         0.3 | 3164.3 |     638.6 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# Starting pax to process run 5891d3421343d0035501d339
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0800_170201_122330
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 29970003359.0000 mongos
# xamsdata0
# 5891d3421343d0035501d339
# 12 hi
# 2018562
# MongoDBInputOnline MainProcess L160 INFO Found 2018562 pulses
# Event: 2018562it [10:11, 3299.25it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  30.1 |         0.1 |        |     184.4 |
# | EncodeZPickle      |  51.6 |         0.2 |        |     315.6 |
# | WriteZipped        |  18.3 |         0.1 |        |     111.9 |
# | TOTAL              | 100.0 |         0.3 | 3299.2 |     611.8 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# Starting pax to process run 5891d46d370543c68f2b0ebe
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0775_170201_122829
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 30179442203.0000 mongos
# xamsdata0
# 5891d46d370543c68f2b0ebe
# 12 hi
# 2032512
# MongoDBInputOnline MainProcess L160 INFO Found 2032512 pulses
# Event: 2032512it [10:29, 3229.97it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  30.4 |         0.1 |        |     191.0 |
# | EncodeZPickle      |  51.4 |         0.2 |        |     323.6 |
# | WriteZipped        |  18.2 |         0.1 |        |     114.6 |
# | TOTAL              | 100.0 |         0.3 | 3230.0 |     629.3 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# processor MainProcess L66 INFO This is PAX version 6.2.1, running with configuration for XAMS.
# processor MainProcess L77 WARNING You did not specify any configuration for the waveform simulator!
# If you attempt to load the waveform simulator, pax will crash!
# Starting pax to process run 5891d5ff5bd3ea908506b9ca
# WriteZipped MainProcess L230 INFO Creating output directory /home/xams/xams/PMT12_gain/K_series/K0750_170201_123511
# Event: 0it [00:00, ?it/s]MongoDBInputOnline MainProcess L155 INFO Searching after 0.000 mongos until 30668098741.0000 mongos
# xamsdata0
# 5891d5ff5bd3ea908506b9ca
# 12 hi
# 2065350
# MongoDBInputOnline MainProcess L160 INFO Found 2065350 pulses
# Event: 2065350it [10:31, 3268.22it/s]
# processor MainProcess L318 INFO All events from input source have been processed.
# processor MainProcess L372 INFO Timing report:
# +--------------------+-------+-------------+--------+-----------+
# | Plugin             |     % | /event (ms) |    #/s | Total (s) |
# +--------------------+-------+-------------+--------+-----------+
# | MongoDBInputOnline |  30.1 |         0.1 |        |     190.5 |
# | EncodeZPickle      |  51.6 |         0.2 |        |     326.0 |
# | WriteZipped        |  18.3 |         0.1 |        |     115.4 |
# | TOTAL              | 100.0 |         0.3 | 3268.2 |     632.0 |
# +--------------------+-------+-------------+--------+-----------+
# Pax is done!
# Temporary nap to prevent infinite print or something
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# 0 runs to do
# No more runs to process, waiting a while...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fcdc244c2af0> in <module>()
#       6     if not runs_todo:
#       7         print("No more runs to process, waiting a while...")
# ----> 8         time.sleep(10)
#       9         continue
#      10
#
# KeyboardInterrupt:

# %%
runs_in_progress = list(collection.find({ 'end' : {'$exists': True}}, projection=['_id']))
if len(runs_in_progress)
